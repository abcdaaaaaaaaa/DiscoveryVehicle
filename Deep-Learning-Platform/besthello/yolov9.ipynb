# %% [markdown]
# (Runtime -> Change runtime type -> A100 GPU) (Runtime -> Run all)

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !scp '/content/drive/MyDrive/yolov9/data.zip' '/content/data.zip'

# !unzip '/content/data.zip' -d '/content/'

# %%
# !git clone https://github.com/WongKinYiu/yolov9

# %%
# %cd yolov9

# %%
# !wget https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !pip install -r requirements.txt

# %%
# !python train.py \
--batch 35 --epochs 215 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data /content/drive/MyDrive/yolov9/coco.yaml \
--weights /content/yolov9/gelan-e.pt \
--cfg /content/yolov9/models/detect/gelan-e.yaml \
--hyp hyp.scratch-high.yaml

# %%
# !cp -rn "runs/train/exp" "/content/drive/MyDrive/yolov9"
