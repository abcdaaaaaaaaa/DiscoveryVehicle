# %% [markdown]
# (Runtime -> Change runtime type -> T4 GPU)
# (Runtime -> Run all)

# %%
# !nvidia-smi

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')

# %%
# !scp '/content/gdrive/My Drive/yolov9/data.zip' '/content/data.zip'

# !unzip '/content/data.zip' -d '/content/'

# %%
# !git clone https://github.com/WongKinYiu/yolov9

# %%
# %cd yolov9

# %%
# !wget https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt

# %%
# !pip install -r requirements.txt

# %%
# !python train.py \
--batch 16 --epochs 150 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data /content/gdrive/MyDrive/yolov9/coco.yaml \
--weights /content/yolov9/yolov9-e.pt \
--cfg /content/yolov9/models/detect/yolov9-e.yaml \
--hyp hyp.scratch-high.yaml

# %%
# !cp -rn "runs/train/exp/weights/best.pt" "/content/gdrive/MyDrive/yolov9"

# %%
Image(filename=f"/content/yolov9/runs/train/exp/results.png", width=1000)

# %%
Image(filename=f"/content/yolov9/runs/train/exp/labels.jpg", width=1000)

# %%
Image(filename=f"/content/yolov9/runs/train/exp/confusion_matrix.png", width=1000)
